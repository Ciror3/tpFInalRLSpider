# %%
import sys, os
import matplotlib.pyplot as plt
sys.path.append(os.path.abspath(".."))
from enviroment import SpiderEnv
from stable_baselines3.common.env_checker import check_env

from stable_baselines3 import PPO
# Out:
# /home/ciror/.local/lib/python3.10/site-packages/matplotlib/projections/__init__.py:63: UserWarning: Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
#   warnings.warn("Unable to import Axes3D. This may be due to multiple versions of "

# %%
env = SpiderEnv(render_mode=None)
check_env(env, warn=True, skip_render_check=True)

# %%
env = SpiderEnv(render_mode=None)

model = PPO(
    "MlpPolicy",
    env,
    verbose=1,
    learning_rate=3e-4,
    batch_size=64,
    gamma=0.99,
)

model.learn(total_timesteps=200_000)
model.save("ppo_spider")
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 165      |
# |    ep_rew_mean     | -278     |
# | time/              |          |
# |    fps             | 3682     |
# |    iterations      | 1        |
# |    time_elapsed    | 0        |
# |    total_timesteps | 1024     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 177         |
# |    ep_rew_mean          | -356        |
# | time/                   |             |
# |    fps                  | 1878        |
# |    iterations           | 2           |
# |    time_elapsed         | 1           |
# |    total_timesteps      | 2048        |
# | train/                  |             |
# |    approx_kl            | 0.008970888 |
# |    clip_fraction        | 0.0536      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.19       |
# |    explained_variance   | -0.00121    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 389         |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0121     |
# |    value_loss           | 858         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 176         |
# |    ep_rew_mean          | -309        |
# | time/                   |             |
# |    fps                  | 1617        |
# |    iterations           | 3           |
# |    time_elapsed         | 1           |
# |    total_timesteps      | 3072        |
# | train/                  |             |
# |    approx_kl            | 0.006717651 |
# |    clip_fraction        | 0.0321      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.18       |
# |    explained_variance   | -0.0567     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 593         |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0109     |
# |    value_loss           | 1.47e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 178         |
# |    ep_rew_mean          | -292        |
# | time/                   |             |
# |    fps                  | 1518        |
# |    iterations           | 4           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.007780719 |
# |    clip_fraction        | 0.0424      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.17       |
# |    explained_variance   | 0.0278      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 158         |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0165     |
# |    value_loss           | 374         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | -271        |
# | time/                   |             |
# |    fps                  | 1465        |
# |    iterations           | 5           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 5120        |
# | train/                  |             |
# |    approx_kl            | 0.008374957 |
# |    clip_fraction        | 0.0495      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.15       |
# |    explained_variance   | 0.000327    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 87.1        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0128     |
# |    value_loss           | 268         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | -250        |
# | time/                   |             |
# |    fps                  | 1432        |
# |    iterations           | 6           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.008843663 |
# |    clip_fraction        | 0.0679      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.13       |
# |    explained_variance   | 0.0174      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 49.2        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0135     |
# |    value_loss           | 147         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 167         |
# |    ep_rew_mean          | -217        |
# | time/                   |             |
# |    fps                  | 1505        |
# |    iterations           | 7           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 7168        |
# | train/                  |             |
# |    approx_kl            | 0.009690696 |
# |    clip_fraction        | 0.066       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.11       |
# |    explained_variance   | 0.013       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 39.6        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0098     |
# |    value_loss           | 90.1        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 163        |
# |    ep_rew_mean          | -201       |
# | time/                   |            |
# |    fps                  | 1560       |
# |    iterations           | 8          |
# |    time_elapsed         | 5          |
# |    total_timesteps      | 8192       |
# | train/                  |            |
# |    approx_kl            | 0.01253635 |
# |    clip_fraction        | 0.113      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.1       |
# |    explained_variance   | -0.00674   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 23         |
# |    n_updates            | 70         |
# |    policy_gradient_loss | -0.00976   |
# |    value_loss           | 67.5       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 142         |
# |    ep_rew_mean          | -166        |
# | time/                   |             |
# |    fps                  | 1604        |
# |    iterations           | 9           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 9216        |
# | train/                  |             |
# |    approx_kl            | 0.010840728 |
# |    clip_fraction        | 0.07        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.07       |
# |    explained_variance   | 0.00165     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 19.1        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00904    |
# |    value_loss           | 72.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 131         |
# |    ep_rew_mean          | -145        |
# | time/                   |             |
# |    fps                  | 1645        |
# |    iterations           | 10          |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.009567306 |
# |    clip_fraction        | 0.052       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.07       |
# |    explained_variance   | -0.000132   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 42.7        |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00654    |
# |    value_loss           | 138         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 118         |
# |    ep_rew_mean          | -123        |
# | time/                   |             |
# |    fps                  | 1682        |
# |    iterations           | 11          |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 11264       |
# | train/                  |             |
# |    approx_kl            | 0.012913149 |
# |    clip_fraction        | 0.0943      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.03       |
# |    explained_variance   | -0.000702   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 53.2        |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0143     |
# |    value_loss           | 111         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 107          |
# |    ep_rew_mean          | -90.2        |
# | time/                   |              |
# |    fps                  | 1710         |
# |    iterations           | 12           |
# |    time_elapsed         | 7            |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0076966844 |
# |    clip_fraction        | 0.0346       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.01        |
# |    explained_variance   | 0.00637      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 40.5         |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.00621     |
# |    value_loss           | 91.5         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 94.5        |
# |    ep_rew_mean          | -64.8       |
# | time/                   |             |
# |    fps                  | 1672        |
# |    iterations           | 13          |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 13312       |
# | train/                  |             |
# |    approx_kl            | 0.009252824 |
# |    clip_fraction        | 0.0732      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.98       |
# |    explained_variance   | 0.029       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 29.7        |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00949    |
# |    value_loss           | 68.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 73.2        |
# |    ep_rew_mean          | -40.7       |
# | time/                   |             |
# |    fps                  | 1696        |
# |    iterations           | 14          |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.008985047 |
# |    clip_fraction        | 0.0776      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.95       |
# |    explained_variance   | 0.0282      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 14.7        |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0104     |
# |    value_loss           | 39          |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60.6         |
# |    ep_rew_mean          | -31.2        |
# | time/                   |              |
# |    fps                  | 1722         |
# |    iterations           | 15           |
# |    time_elapsed         | 8            |
# |    total_timesteps      | 15360        |
# | train/                  |              |
# |    approx_kl            | 0.0068480163 |
# |    clip_fraction        | 0.0315       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.88        |
# |    explained_variance   | -0.0792      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 52.9         |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.0062      |
# |    value_loss           | 78.1         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 52.8        |
# |    ep_rew_mean          | -26.7       |
# | time/                   |             |
# |    fps                  | 1734        |
# |    iterations           | 16          |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.005121391 |
# |    clip_fraction        | 0.0242      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.81       |
# |    explained_variance   | -0.0759     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 30          |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.00622    |
# |    value_loss           | 59.7        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 42           |
# |    ep_rew_mean          | -21.3        |
# | time/                   |              |
# |    fps                  | 1700         |
# |    iterations           | 17           |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 17408        |
# | train/                  |              |
# |    approx_kl            | 0.0067401733 |
# |    clip_fraction        | 0.0461       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.8         |
# |    explained_variance   | 0.0445       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 26.8         |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.0071      |
# |    value_loss           | 47.5         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 40.7        |
# |    ep_rew_mean          | -19.3       |
# | time/                   |             |
# |    fps                  | 1671        |
# |    iterations           | 18          |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.010072762 |
# |    clip_fraction        | 0.0792      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.75       |
# |    explained_variance   | 0.0358      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 18.2        |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0125     |
# |    value_loss           | 40.2        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 37.1         |
# |    ep_rew_mean          | -18          |
# | time/                   |              |
# |    fps                  | 1645         |
# |    iterations           | 19           |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 19456        |
# | train/                  |              |
# |    approx_kl            | 0.0076252157 |
# |    clip_fraction        | 0.0524       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.74        |
# |    explained_variance   | 0.0723       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 15.6         |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.00607     |
# |    value_loss           | 29.9         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 40.9        |
# |    ep_rew_mean          | -18.9       |
# | time/                   |             |
# |    fps                  | 1622        |
# |    iterations           | 20          |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.010570981 |
# |    clip_fraction        | 0.0567      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.63       |
# |    explained_variance   | 0.243       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 13.5        |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0138     |
# |    value_loss           | 31.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 41.7        |
# |    ep_rew_mean          | -19.6       |
# | time/                   |             |
# |    fps                  | 1598        |
# |    iterations           | 21          |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 21504       |
# | train/                  |             |
# |    approx_kl            | 0.013848703 |
# |    clip_fraction        | 0.127       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.71       |
# |    explained_variance   | 0.104       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.48        |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0119     |
# |    value_loss           | 21          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 39.5        |
# |    ep_rew_mean          | -19.3       |
# | time/                   |             |
# |    fps                  | 1583        |
# |    iterations           | 22          |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.009388704 |
# |    clip_fraction        | 0.106       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.63       |
# |    explained_variance   | 0.271       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 12.5        |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0133     |
# |    value_loss           | 25.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 42.5        |
# |    ep_rew_mean          | -19.6       |
# | time/                   |             |
# |    fps                  | 1568        |
# |    iterations           | 23          |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 23552       |
# | train/                  |             |
# |    approx_kl            | 0.008771304 |
# |    clip_fraction        | 0.0634      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.6        |
# |    explained_variance   | 0.372       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 10          |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0089     |
# |    value_loss           | 25.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 44.7        |
# |    ep_rew_mean          | -20.1       |
# | time/                   |             |
# |    fps                  | 1585        |
# |    iterations           | 24          |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.007870204 |
# |    clip_fraction        | 0.0629      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.7        |
# |    explained_variance   | 0.286       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.99        |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00665    |
# |    value_loss           | 15.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 41          |
# |    ep_rew_mean          | -18.3       |
# | time/                   |             |
# |    fps                  | 1570        |
# |    iterations           | 25          |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 25600       |
# | train/                  |             |
# |    approx_kl            | 0.010789178 |
# |    clip_fraction        | 0.0688      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.66       |
# |    explained_variance   | 0.321       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.7         |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.00952    |
# |    value_loss           | 12.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 44.7        |
# |    ep_rew_mean          | -18.4       |
# | time/                   |             |
# |    fps                  | 1559        |
# |    iterations           | 26          |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.008183642 |
# |    clip_fraction        | 0.0572      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.53       |
# |    explained_variance   | 0.499       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.2         |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.00747    |
# |    value_loss           | 17          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 36          |
# |    ep_rew_mean          | -14.5       |
# | time/                   |             |
# |    fps                  | 1575        |
# |    iterations           | 27          |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 27648       |
# | train/                  |             |
# |    approx_kl            | 0.011932763 |
# |    clip_fraction        | 0.104       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.55       |
# |    explained_variance   | 0.588       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.26        |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.0124     |
# |    value_loss           | 11          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 36.2        |
# |    ep_rew_mean          | -15.1       |
# | time/                   |             |
# |    fps                  | 1591        |
# |    iterations           | 28          |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.008813276 |
# |    clip_fraction        | 0.0782      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.45       |
# |    explained_variance   | 0.525       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.71        |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.00616    |
# |    value_loss           | 10.2        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 30.1         |
# |    ep_rew_mean          | -12.9        |
# | time/                   |              |
# |    fps                  | 1605         |
# |    iterations           | 29           |
# |    time_elapsed         | 18           |
# |    total_timesteps      | 29696        |
# | train/                  |              |
# |    approx_kl            | 0.0069468906 |
# |    clip_fraction        | 0.0435       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.44        |
# |    explained_variance   | 0.763        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.19         |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -0.00618     |
# |    value_loss           | 7.65         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 30.5        |
# |    ep_rew_mean          | -13.9       |
# | time/                   |             |
# |    fps                  | 1583        |
# |    iterations           | 30          |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.010025458 |
# |    clip_fraction        | 0.12        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | 0.738       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.51        |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.0149     |
# |    value_loss           | 5.71        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 28.4        |
# |    ep_rew_mean          | -12.8       |
# | time/                   |             |
# |    fps                  | 1596        |
# |    iterations           | 31          |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 31744       |
# | train/                  |             |
# |    approx_kl            | 0.008990724 |
# |    clip_fraction        | 0.0662      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | 0.833       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.09        |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.00951    |
# |    value_loss           | 5.53        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 26.8        |
# |    ep_rew_mean          | -12.2       |
# | time/                   |             |
# |    fps                  | 1610        |
# |    iterations           | 32          |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.010692668 |
# |    clip_fraction        | 0.0824      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.31       |
# |    explained_variance   | 0.852       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.62        |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.0109     |
# |    value_loss           | 3.6         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 26.1        |
# |    ep_rew_mean          | -10.6       |
# | time/                   |             |
# |    fps                  | 1623        |
# |    iterations           | 33          |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 33792       |
# | train/                  |             |
# |    approx_kl            | 0.009769909 |
# |    clip_fraction        | 0.139       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.2        |
# |    explained_variance   | 0.891       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.01        |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.0156     |
# |    value_loss           | 3.05        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 23.7        |
# |    ep_rew_mean          | -9.87       |
# | time/                   |             |
# |    fps                  | 1635        |
# |    iterations           | 34          |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.011829114 |
# |    clip_fraction        | 0.0975      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.22       |
# |    explained_variance   | 0.892       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.98        |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.0112     |
# |    value_loss           | 1.83        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 21.6        |
# |    ep_rew_mean          | -9.88       |
# | time/                   |             |
# |    fps                  | 1623        |
# |    iterations           | 35          |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 35840       |
# | train/                  |             |
# |    approx_kl            | 0.011078116 |
# |    clip_fraction        | 0.117       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.11       |
# |    explained_variance   | 0.937       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.05        |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.0162     |
# |    value_loss           | 1.87        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 21.8        |
# |    ep_rew_mean          | -8.79       |
# | time/                   |             |
# |    fps                  | 1612        |
# |    iterations           | 36          |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.012012277 |
# |    clip_fraction        | 0.181       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.983      |
# |    explained_variance   | 0.954       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.03        |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.0237     |
# |    value_loss           | 1.32        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 22.3        |
# |    ep_rew_mean          | -9.3        |
# | time/                   |             |
# |    fps                  | 1601        |
# |    iterations           | 37          |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 37888       |
# | train/                  |             |
# |    approx_kl            | 0.016792288 |
# |    clip_fraction        | 0.162       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1          |
# |    explained_variance   | 0.908       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.403       |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.0184     |
# |    value_loss           | 1.14        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 21          |
# |    ep_rew_mean          | -8.35       |
# | time/                   |             |
# |    fps                  | 1612        |
# |    iterations           | 38          |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.018232478 |
# |    clip_fraction        | 0.17        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.865      |
# |    explained_variance   | 0.952       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.34        |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.0235     |
# |    value_loss           | 0.882       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 21.7        |
# |    ep_rew_mean          | -7.39       |
# | time/                   |             |
# |    fps                  | 1620        |
# |    iterations           | 39          |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 39936       |
# | train/                  |             |
# |    approx_kl            | 0.011992758 |
# |    clip_fraction        | 0.0995      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.911      |
# |    explained_variance   | 0.951       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.186       |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.0147     |
# |    value_loss           | 0.658       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 22          |
# |    ep_rew_mean          | -7.44       |
# | time/                   |             |
# |    fps                  | 1608        |
# |    iterations           | 40          |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.018191747 |
# |    clip_fraction        | 0.164       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.778      |
# |    explained_variance   | 0.968       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.258       |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.0179     |
# |    value_loss           | 0.548       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 20.1        |
# |    ep_rew_mean          | -6.45       |
# | time/                   |             |
# |    fps                  | 1596        |
# |    iterations           | 41          |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 41984       |
# | train/                  |             |
# |    approx_kl            | 0.004850695 |
# |    clip_fraction        | 0.0472      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.841      |
# |    explained_variance   | 0.953       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.261       |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.0073     |
# |    value_loss           | 0.565       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 21         |
# |    ep_rew_mean          | -6.23      |
# | time/                   |            |
# |    fps                  | 1605       |
# |    iterations           | 42         |
# |    time_elapsed         | 26         |
# |    total_timesteps      | 43008      |
# | train/                  |            |
# |    approx_kl            | 0.01568787 |
# |    clip_fraction        | 0.0975     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.838     |
# |    explained_variance   | 0.957      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.147      |
# |    n_updates            | 410        |
# |    policy_gradient_loss | -0.0116    |
# |    value_loss           | 0.492      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 21.6        |
# |    ep_rew_mean          | -6.2        |
# | time/                   |             |
# |    fps                  | 1613        |
# |    iterations           | 43          |
# |    time_elapsed         | 27          |
# |    total_timesteps      | 44032       |
# | train/                  |             |
# |    approx_kl            | 0.010079375 |
# |    clip_fraction        | 0.0737      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.94       |
# |    explained_variance   | 0.966       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.157       |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.0139     |
# |    value_loss           | 0.475       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 23.6        |
# |    ep_rew_mean          | -6.28       |
# | time/                   |             |
# |    fps                  | 1602        |
# |    iterations           | 44          |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.008816049 |
# |    clip_fraction        | 0.0819      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.958      |
# |    explained_variance   | 0.957       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.416       |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.0113     |
# |    value_loss           | 0.608       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 24.1        |
# |    ep_rew_mean          | -6.25       |
# | time/                   |             |
# |    fps                  | 1593        |
# |    iterations           | 45          |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 46080       |
# | train/                  |             |
# |    approx_kl            | 0.010903563 |
# |    clip_fraction        | 0.055       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.892      |
# |    explained_variance   | 0.958       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.181       |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.0126     |
# |    value_loss           | 0.479       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 24.2         |
# |    ep_rew_mean          | -6.85        |
# | time/                   |              |
# |    fps                  | 1583         |
# |    iterations           | 46           |
# |    time_elapsed         | 29           |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0077074273 |
# |    clip_fraction        | 0.0788       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.946       |
# |    explained_variance   | 0.947        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.256        |
# |    n_updates            | 450          |
# |    policy_gradient_loss | -0.0123      |
# |    value_loss           | 0.671        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 25.7        |
# |    ep_rew_mean          | -7.09       |
# | time/                   |             |
# |    fps                  | 1574        |
# |    iterations           | 47          |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 48128       |
# | train/                  |             |
# |    approx_kl            | 0.005448833 |
# |    clip_fraction        | 0.0435      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.896      |
# |    explained_variance   | 0.961       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.29        |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.011      |
# |    value_loss           | 0.615       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 25.5        |
# |    ep_rew_mean          | -6.48       |
# | time/                   |             |
# |    fps                  | 1562        |
# |    iterations           | 48          |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.008603562 |
# |    clip_fraction        | 0.105       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.963      |
# |    explained_variance   | 0.948       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.371       |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.0176     |
# |    value_loss           | 0.874       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 27.9        |
# |    ep_rew_mean          | -5.9        |
# | time/                   |             |
# |    fps                  | 1555        |
# |    iterations           | 49          |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 50176       |
# | train/                  |             |
# |    approx_kl            | 0.009732415 |
# |    clip_fraction        | 0.105       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.938      |
# |    explained_variance   | 0.924       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.406       |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.0193     |
# |    value_loss           | 0.838       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 33.4        |
# |    ep_rew_mean          | -4.82       |
# | time/                   |             |
# |    fps                  | 1547        |
# |    iterations           | 50          |
# |    time_elapsed         | 33          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.007833004 |
# |    clip_fraction        | 0.106       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.894      |
# |    explained_variance   | 0.903       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.597       |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.0196     |
# |    value_loss           | 1.25        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 39.5         |
# |    ep_rew_mean          | -4.1         |
# | time/                   |              |
# |    fps                  | 1540         |
# |    iterations           | 51           |
# |    time_elapsed         | 33           |
# |    total_timesteps      | 52224        |
# | train/                  |              |
# |    approx_kl            | 0.0088821715 |
# |    clip_fraction        | 0.105        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.991       |
# |    explained_variance   | 0.741        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.03         |
# |    n_updates            | 500          |
# |    policy_gradient_loss | -0.0118      |
# |    value_loss           | 1.63         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 47.3         |
# |    ep_rew_mean          | -2.96        |
# | time/                   |              |
# |    fps                  | 1533         |
# |    iterations           | 52           |
# |    time_elapsed         | 34           |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 0.0074116075 |
# |    clip_fraction        | 0.0917       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.02        |
# |    explained_variance   | 0.785        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.432        |
# |    n_updates            | 510          |
# |    policy_gradient_loss | -0.0153      |
# |    value_loss           | 1.36         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 55.5         |
# |    ep_rew_mean          | -2.02        |
# | time/                   |              |
# |    fps                  | 1529         |
# |    iterations           | 53           |
# |    time_elapsed         | 35           |
# |    total_timesteps      | 54272        |
# | train/                  |              |
# |    approx_kl            | 0.0053118416 |
# |    clip_fraction        | 0.0511       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.981       |
# |    explained_variance   | 0.668        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.704        |
# |    n_updates            | 520          |
# |    policy_gradient_loss | -0.00699     |
# |    value_loss           | 1.34         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 64          |
# |    ep_rew_mean          | -1.22       |
# | time/                   |             |
# |    fps                  | 1523        |
# |    iterations           | 54          |
# |    time_elapsed         | 36          |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.004472993 |
# |    clip_fraction        | 0.0277      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.938      |
# |    explained_variance   | 0.725       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.23        |
# |    n_updates            | 530         |
# |    policy_gradient_loss | -0.00814    |
# |    value_loss           | 1.88        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 71.9        |
# |    ep_rew_mean          | 0.0453      |
# | time/                   |             |
# |    fps                  | 1518        |
# |    iterations           | 55          |
# |    time_elapsed         | 37          |
# |    total_timesteps      | 56320       |
# | train/                  |             |
# |    approx_kl            | 0.011093905 |
# |    clip_fraction        | 0.129       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.922      |
# |    explained_variance   | 0.858       |
# |    learning_rate        | 0.0003      |
# ...
# | time/                   |              |
# |    fps                  | 1421         |
# |    iterations           | 179          |
# |    time_elapsed         | 128          |
# |    total_timesteps      | 183296       |
# | train/                  |              |
# |    approx_kl            | 0.0014065951 |
# |    clip_fraction        | 0.0183       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.212       |
# |    explained_variance   | 0.428        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.1          |
# |    n_updates            | 1780         |
# |    policy_gradient_loss | 8.3e-05      |
# |    value_loss           | 6.35         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 169          |
# |    ep_rew_mean          | 40.1         |
# | time/                   |              |
# |    fps                  | 1422         |
# |    iterations           | 180          |
# |    time_elapsed         | 129          |
# |    total_timesteps      | 184320       |
# | train/                  |              |
# |    approx_kl            | 0.0010367562 |
# |    clip_fraction        | 0.0169       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.22        |
# |    explained_variance   | 0.148        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.53         |
# |    n_updates            | 1790         |
# |    policy_gradient_loss | -0.00222     |
# |    value_loss           | 17.5         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 170          |
# |    ep_rew_mean          | 40.6         |
# | time/                   |              |
# |    fps                  | 1419         |
# |    iterations           | 181          |
# |    time_elapsed         | 130          |
# |    total_timesteps      | 185344       |
# | train/                  |              |
# |    approx_kl            | 0.0008103564 |
# |    clip_fraction        | 0.0262       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.232       |
# |    explained_variance   | 0.299        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.82         |
# |    n_updates            | 1800         |
# |    policy_gradient_loss | -0.000461    |
# |    value_loss           | 6.72         |
# ------------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 170       |
# |    ep_rew_mean          | 40.3      |
# | time/                   |           |
# |    fps                  | 1419      |
# |    iterations           | 182       |
# |    time_elapsed         | 131       |
# |    total_timesteps      | 186368    |
# | train/                  |           |
# |    approx_kl            | 0.2733442 |
# |    clip_fraction        | 0.106     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.264    |
# |    explained_variance   | 0.891     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0397   |
# |    n_updates            | 1810      |
# |    policy_gradient_loss | -0.026    |
# |    value_loss           | 0.149     |
# ---------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 167          |
# |    ep_rew_mean          | 39.5         |
# | time/                   |              |
# |    fps                  | 1419         |
# |    iterations           | 183          |
# |    time_elapsed         | 132          |
# |    total_timesteps      | 187392       |
# | train/                  |              |
# |    approx_kl            | 0.0014344763 |
# |    clip_fraction        | 0.027        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.22        |
# |    explained_variance   | 0.497        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.33         |
# |    n_updates            | 1820         |
# |    policy_gradient_loss | -0.00401     |
# |    value_loss           | 11.8         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 169          |
# |    ep_rew_mean          | 40.5         |
# | time/                   |              |
# |    fps                  | 1419         |
# |    iterations           | 184          |
# |    time_elapsed         | 132          |
# |    total_timesteps      | 188416       |
# | train/                  |              |
# |    approx_kl            | 0.0027089643 |
# |    clip_fraction        | 0.0457       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.222       |
# |    explained_variance   | 0.108        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 12.6         |
# |    n_updates            | 1830         |
# |    policy_gradient_loss | -0.00521     |
# |    value_loss           | 12.7         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 172          |
# |    ep_rew_mean          | 41.5         |
# | time/                   |              |
# |    fps                  | 1416         |
# |    iterations           | 185          |
# |    time_elapsed         | 133          |
# |    total_timesteps      | 189440       |
# | train/                  |              |
# |    approx_kl            | 0.0038498112 |
# |    clip_fraction        | 0.0515       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.23        |
# |    explained_variance   | 0.284        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.314        |
# |    n_updates            | 1840         |
# |    policy_gradient_loss | -0.00113     |
# |    value_loss           | 5.13         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 170          |
# |    ep_rew_mean          | 41.4         |
# | time/                   |              |
# |    fps                  | 1418         |
# |    iterations           | 186          |
# |    time_elapsed         | 134          |
# |    total_timesteps      | 190464       |
# | train/                  |              |
# |    approx_kl            | 0.0026719067 |
# |    clip_fraction        | 0.0321       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.215       |
# |    explained_variance   | 0.811        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.188        |
# |    n_updates            | 1850         |
# |    policy_gradient_loss | -0.00498     |
# |    value_loss           | 0.206        |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 168           |
# |    ep_rew_mean          | 40.7          |
# | time/                   |               |
# |    fps                  | 1420          |
# |    iterations           | 187           |
# |    time_elapsed         | 134           |
# |    total_timesteps      | 191488        |
# | train/                  |               |
# |    approx_kl            | 0.00040181522 |
# |    clip_fraction        | 0.0085        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.227        |
# |    explained_variance   | 0.34          |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.19          |
# |    n_updates            | 1860          |
# |    policy_gradient_loss | 1.39e-06      |
# |    value_loss           | 18            |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 170          |
# |    ep_rew_mean          | 41.6         |
# | time/                   |              |
# |    fps                  | 1421         |
# |    iterations           | 188          |
# |    time_elapsed         | 135          |
# |    total_timesteps      | 192512       |
# | train/                  |              |
# |    approx_kl            | 0.0014925981 |
# |    clip_fraction        | 0.00684      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.185       |
# |    explained_variance   | 0.048        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.56         |
# |    n_updates            | 1870         |
# |    policy_gradient_loss | -0.00332     |
# |    value_loss           | 8.37         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 173         |
# |    ep_rew_mean          | 41.9        |
# | time/                   |             |
# |    fps                  | 1422        |
# |    iterations           | 189         |
# |    time_elapsed         | 136         |
# |    total_timesteps      | 193536      |
# | train/                  |             |
# |    approx_kl            | 0.016449109 |
# |    clip_fraction        | 0.072       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.277      |
# |    explained_variance   | 0.903       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.028      |
# |    n_updates            | 1880        |
# |    policy_gradient_loss | -0.0154     |
# |    value_loss           | 0.0781      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 171         |
# |    ep_rew_mean          | 41.3        |
# | time/                   |             |
# |    fps                  | 1422        |
# |    iterations           | 190         |
# |    time_elapsed         | 136         |
# |    total_timesteps      | 194560      |
# | train/                  |             |
# |    approx_kl            | 0.007894752 |
# |    clip_fraction        | 0.0995      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.312      |
# |    explained_variance   | 0.987       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00977    |
# |    n_updates            | 1890        |
# |    policy_gradient_loss | -0.013      |
# |    value_loss           | 0.0758      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 167        |
# |    ep_rew_mean          | 40.3       |
# | time/                   |            |
# |    fps                  | 1425       |
# |    iterations           | 191        |
# |    time_elapsed         | 137        |
# |    total_timesteps      | 195584     |
# | train/                  |            |
# |    approx_kl            | 0.00611478 |
# |    clip_fraction        | 0.072      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.306     |
# |    explained_variance   | 0.521      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0968     |
# |    n_updates            | 1900       |
# |    policy_gradient_loss | -0.00733   |
# |    value_loss           | 2.89       |
# ----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 167           |
# |    ep_rew_mean          | 40.2          |
# | time/                   |               |
# |    fps                  | 1423          |
# |    iterations           | 192           |
# |    time_elapsed         | 138           |
# |    total_timesteps      | 196608        |
# | train/                  |               |
# |    approx_kl            | 0.00036012754 |
# |    clip_fraction        | 0.024         |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.266        |
# |    explained_variance   | 0.118         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 14.9          |
# |    n_updates            | 1910          |
# |    policy_gradient_loss | -0.00403      |
# |    value_loss           | 29.6          |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 167          |
# |    ep_rew_mean          | 40.2         |
# | time/                   |              |
# |    fps                  | 1421         |
# |    iterations           | 193          |
# |    time_elapsed         | 139          |
# |    total_timesteps      | 197632       |
# | train/                  |              |
# |    approx_kl            | 0.0010182229 |
# |    clip_fraction        | 0.0154       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.281       |
# |    explained_variance   | 0.251        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 14.1         |
# |    n_updates            | 1920         |
# |    policy_gradient_loss | -0.00239     |
# |    value_loss           | 17.4         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 163          |
# |    ep_rew_mean          | 39.3         |
# | time/                   |              |
# |    fps                  | 1419         |
# |    iterations           | 194          |
# |    time_elapsed         | 139          |
# |    total_timesteps      | 198656       |
# | train/                  |              |
# |    approx_kl            | 0.0015199892 |
# |    clip_fraction        | 0.0232       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.262       |
# |    explained_variance   | 0.428        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.28         |
# |    n_updates            | 1930         |
# |    policy_gradient_loss | -0.000809    |
# |    value_loss           | 5.6          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 161          |
# |    ep_rew_mean          | 38.8         |
# | time/                   |              |
# |    fps                  | 1418         |
# |    iterations           | 195          |
# |    time_elapsed         | 140          |
# |    total_timesteps      | 199680       |
# | train/                  |              |
# |    approx_kl            | 0.0026709554 |
# |    clip_fraction        | 0.0199       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.248       |
# |    explained_variance   | 0.278        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.62         |
# |    n_updates            | 1940         |
# |    policy_gradient_loss | -0.000963    |
# |    value_loss           | 12.2         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 163          |
# |    ep_rew_mean          | 39.6         |
# | time/                   |              |
# |    fps                  | 1417         |
# |    iterations           | 196          |
# |    time_elapsed         | 141          |
# |    total_timesteps      | 200704       |
# | train/                  |              |
# |    approx_kl            | 0.0009500176 |
# |    clip_fraction        | 0.0138       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.231       |
# |    explained_variance   | 0.257        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.33         |
# |    n_updates            | 1950         |
# |    policy_gradient_loss | 2.63e-05     |
# |    value_loss           | 19.1         |
# ------------------------------------------
