# %%
from enviroment import SpiderEnv
from stable_baselines3 import PPO

# %%
env = SpiderEnv(render_mode="human")
model = PPO.load("models_spider/run_20251122_152054/ppo_spider_final.zip", env=env)

obs, info = env.reset()
for _ in range(1000):
    action, _ = model.predict(obs, deterministic=True)
    obs, reward, terminated, truncated, info = env.step(int(action))
    print(info)
    env.render()
    if terminated or truncated:
        obs, info = env.reset()
# Out:
# c:\Users\Ciro\anaconda3\envs\rl\lib\site-packages\stable_baselines3\common\on_policy_algorithm.py:150: UserWarning: You are trying to run PPO on the GPU, but it is primarily intended to run on the CPU when not using a CNN policy (you are using ActorCriticPolicy which should be a MlpPolicy). See https://github.com/DLR-RM/stable-baselines3/issues/1245 for more info. You can pass `device='cpu'` or `export CUDA_VISIBLE_DEVICES=` to force using the CPU.Note: The model will train, but the GPU utilization will be poor and the training might take longer than on CPU.
#   warnings.warn(
# {'comando': 267, 'target': array([-0.42478355, -0.42647291])}
# {'comando': 227, 'target': array([-0.64120834, -0.08876264])}
# {'comando': 267, 'target': array([ 0.07379166, -0.08876264])}
# {'comando': 267, 'target': array([-2.49537836, -0.84801815])}
# {'comando': 267, 'target': array([-1.78037836, -0.84801815])}
# {'comando': 267, 'target': array([-1.06537836, -0.84801815])}
# {'comando': 227, 'target': array([-1.4080145, -0.0971547])}
# {'comando': 267, 'target': array([-0.6930145, -0.0971547])}
# {'comando': 256, 'target': array([-0.63955232, -0.03509313])}
# {'comando': 267, 'target': array([ 0.07544768, -0.03509313])}
# {'comando': 267, 'target': array([-2.17666265, -1.40661325])}
# {'comando': 227, 'target': array([-2.64490225,  0.03357384])}
# {'comando': 267, 'target': array([-1.92990225,  0.03357384])}
# {'comando': 267, 'target': array([-1.21490225,  0.03357384])}
# {'comando': 267, 'target': array([-0.49990225,  0.03357384])}
# {'comando': 267, 'target': array([0.21509775, 0.03357384])}
# {'comando': 262, 'target': array([0.12579775, 0.03357384])}
# {'comando': 227, 'target': array([-4.37500013, -1.1932163 ])}
# {'comando': 267, 'target': array([-3.66000013, -1.1932163 ])}
# {'comando': 267, 'target': array([-2.94500013, -1.1932163 ])}
# {'comando': 267, 'target': array([-2.23000013, -1.1932163 ])}
# {'comando': 267, 'target': array([-1.51500013, -1.1932163 ])}
# {'comando': 227, 'target': array([-1.9728826 , -0.14454168])}
# {'comando': 267, 'target': array([-1.2578826 , -0.14454168])}
# {'comando': 267, 'target': array([-0.5428826 , -0.14454168])}
# {'comando': 251, 'target': array([-0.63523311, -0.01689356])}
# {'comando': 267, 'target': array([ 0.07976689, -0.01689356])}
# {'comando': 251, 'target': array([-1.06743669, -3.47659837])}
# {'comando': 227, 'target': array([-2.83058327, -2.30752487])}
# {'comando': 227, 'target': array([-3.68203354, -0.37091671])}
# {'comando': 256, 'target': array([-3.64092984, -0.00487063])}
# {'comando': 267, 'target': array([-2.92592984, -0.00487063])}
# {'comando': 267, 'target': array([-2.21092984, -0.00487063])}
# {'comando': 267, 'target': array([-1.49592984, -0.00487063])}
# {'comando': 267, 'target': array([-0.78092984, -0.00487063])}
# {'comando': 267, 'target': array([-0.06592984, -0.00487063])}
# {'comando': 227, 'target': array([-3.59932725, -0.5730958 ])}
# {'comando': 267, 'target': array([-2.88432725, -0.5730958 ])}
# {'comando': 267, 'target': array([-2.16932725, -0.5730958 ])}
# {'comando': 267, 'target': array([-1.45432725, -0.5730958 ])}
# {'comando': 267, 'target': array([-0.73932725, -0.5730958 ])}
# {'comando': 227, 'target': array([-0.98509559, -0.04209816])}
# {'comando': 256, 'target': array([-0.92455963,  0.04924793])}
# {'comando': 267, 'target': array([-0.20955963,  0.04924793])}
# {'comando': 258, 'target': array([-0.14688619,  0.04260655])}
# {'comando': 227, 'target': array([-3.01667938, -0.65940604])}
# {'comando': 267, 'target': array([-2.30167938, -0.65940604])}
# {'comando': 267, 'target': array([-1.58667938, -0.65940604])}
# {'comando': 267, 'target': array([-0.87167938, -0.65940604])}
# {'comando': 227, 'target': array([-1.14309998, -0.04317204])}
# {'comando': 267, 'target': array([-0.42809998, -0.04317204])}
# {'comando': 252, 'target': array([-0.50722542, -0.0039169 ])}
# {'comando': 267, 'target': array([ 0.20777458, -0.0039169 ])}
# {'comando': 262, 'target': array([ 0.11847458, -0.0039169 ])}
# {'comando': 227, 'target': array([-0.66083307, -0.56300025])}
# {'comando': 227, 'target': array([-0.91359971, -0.07603333])}
# {'comando': 256, 'target': array([-0.85686628,  0.00824957])}
# {'comando': 267, 'target': array([-0.14186628,  0.00824957])}
# {'comando': 267, 'target': array([-2.55241701, -1.41184733])}
# {'comando': 267, 'target': array([-1.83741701, -1.41184733])}
# {'comando': 227, 'target': array([-2.36231657, -0.15420351])}
# {'comando': 267, 'target': array([-1.64731657, -0.15420351])}
# {'comando': 256, 'target': array([-1.59472724,  0.00475505])}
# {'comando': 267, 'target': array([-0.87972724,  0.00475505])}
# {'comando': 267, 'target': array([-0.16472724,  0.00475505])}
# {'comando': 267, 'target': array([-2.05951473, -0.63900701])}
# {'comando': 267, 'target': array([-1.34451473, -0.63900701])}
# {'comando': 267, 'target': array([-0.62951473, -0.63900701])}
# {'comando': 227, 'target': array([-0.92833513, -0.15690812])}
# {'comando': 256, 'target': array([-0.87971296, -0.07071811])}
# {'comando': 256, 'target': array([-0.82261555,  0.01010713])}
# {'comando': 267, 'target': array([-0.10761555,  0.01010713])}
# {'comando': 267, 'target': array([-0.41131705, -0.40895578])}
# {'comando': 227, 'target': array([-0.62041008, -0.0813042 ])}
# {'comando': 267, 'target': array([ 0.09458992, -0.0813042 ])}
# {'comando': 227, 'target': array([-4.91041339, -1.50764584])}
# {'comando': 267, 'target': array([-4.19541339, -1.50764584])}
# {'comando': 267, 'target': array([-3.48041339, -1.50764584])}
# {'comando': 267, 'target': array([-2.76541339, -1.50764584])}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 7
#       5 for _ in range(1000):
#       6     action, _ = model.predict(obs, deterministic=True)
# ----> 7     obs, reward, terminated, truncated, info = env.step(int(action))
#       8     print(info)
#       9     env.render()
#
# File c:\Users\Ciro\Desktop\cuatri\rl\tpFInalRLSpider\enviroment.py:325, in SpiderEnv.step(self, action)
#     322 info = {"comando": command, "target": self.target_pos}
#     324 if self.render_mode == "human":
# --> 325     self.render()
#     327 return obs, reward, terminated, truncated, info
#
# File c:\Users\Ciro\Desktop\cuatri\rl\tpFInalRLSpider\enviroment.py:387, in SpiderEnv.render(self)
#     384 self.screen.blit(text_surface, (10, 10))
#     386 pygame.display.flip()
# --> 387 self.clock.tick(self.metadata["render_fps"])
#
# KeyboardInterrupt:
